# %%
import pymongo as mg
import pandas as pd

# %%
client = mg.MongoClient(host='mongodb://localhost:27017')

# %%
database = client['db_NHIS']

# %%
collection = database['NSC2_BNC_V2_1']

# %%
cursor = collection.find({})

# %%
list_BNC_V2_1 = list(cursor)

# %%
list_BNC_V2_1
# Out:
# [{'_id': ObjectId('64d311be82df399014513fb1'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 29140,
#   'GAIBJA_TYPE': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fb2'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 29140,
#   'GAIBJA_TYPE': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fb3'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 29140,
#   'GAIBJA_TYPE': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fb4'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 29140,
#   'GAIBJA_TYPE': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fb5'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 29140,
#   'GAIBJA_TYPE': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fb6'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 29140,
#   'GAIBJA_TYPE': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fb7'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 29170,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fb8'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 47190,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fb9'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 47190,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fba'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 47190,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fbb'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 47190,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fbc'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 47190,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fbd'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 47190,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fbe'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 47190,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fbf'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 41460,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fc0'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 41460,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fc1'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 41460,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fc2'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 41460,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fc3'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 41461,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fc4'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 41461,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fc5'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 41461,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fc6'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 41461,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fc7'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 44760,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fc8'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 44760,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fc9'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 44760,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fca'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 44760,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fcb'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 44760,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fcc'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 44760,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fcd'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fce'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fcf'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fd0'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fd1'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fd2'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fd3'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fd4'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fd5'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fd6'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fd7'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fd8'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 3,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fd9'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fda'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 7,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fdb'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 4392,
#   'SEX': 2,
#   'SGG': 41220,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fdc'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 4392,
#   'SEX': 2,
#   'SGG': 41220,
#   'GAIBJA_TYPE': 6,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fdd'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 4392,
#   'SEX': 2,
#   'SGG': 41220,
#   'GAIBJA_TYPE': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fde'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 4392,
#   'SEX': 2,
#   'SGG': 41220,
#   'GAIBJA_TYPE': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fdf'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 4392,
#   'SEX': 2,
#   'SGG': 41220,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fe0'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 4392,
#   'SEX': 2,
#   'SGG': 41220,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fe1'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 4392,
#   'SEX': 2,
#   'SGG': 11650,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fe2'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 4392,
#   'SEX': 2,
#   'SGG': 11650,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fe3'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 4392,
#   'SEX': 2,
#   'SGG': 11650,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fe4'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 4392,
#   'SEX': 2,
#   'SGG': 41590,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fe5'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 4392,
#   'SEX': 2,
#   'SGG': 41590,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 2,
#   'DSB_TYPE_CD': 5,
#   'SMPL_TYPE_CD': 1,
#   'DSB_SVRT_CD_V2': 1},
#  {'_id': ObjectId('64d311be82df399014513fe6'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26140,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fe7'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26320,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fe8'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26320,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fe9'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26320,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fea'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26140,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513feb'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26140,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fec'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26140,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fed'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26410,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fee'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26350,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fef'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26350,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513ff0'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26350,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513ff1'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26350,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513ff2'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26350,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513ff3'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513ff4'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 6,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513ff5'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513ff6'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 6,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513ff7'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513ff8'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 7,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513ff9'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513ffa'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513ffb'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513ffc'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513ffd'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513ffe'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014513fff'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514000'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514001'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27290,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514002'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27290,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 7,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514003'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27290,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514004'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27290,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514005'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27290,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514006'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27170,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514007'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27170,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514008'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27170,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514009'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27170,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df39901451400a'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27170,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df39901451400b'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27170,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df39901451400c'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27170,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df39901451400d'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27170,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df39901451400e'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27170,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df39901451400f'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48110,
#   'GAIBJA_TYPE': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514010'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48110,
#   'GAIBJA_TYPE': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514011'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48110,
#   'GAIBJA_TYPE': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514012'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48110,
#   'GAIBJA_TYPE': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514013'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48110,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514014'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48110,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514015'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48110,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514016'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48110,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514017'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48110,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514018'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48121,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514019'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48121,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df39901451401a'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48121,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 5,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df39901451401b'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48121,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 5,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df39901451401c'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48121,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 5,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df39901451401d'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df39901451401e'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df39901451401f'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514020'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514021'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514022'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514023'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514024'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514025'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514026'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514027'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514028'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514029'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df39901451402a'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 3,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df39901451402b'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df39901451402c'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df39901451402d'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df39901451402e'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 9,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df39901451402f'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514030'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 9,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514031'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514032'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 9,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514033'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514034'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514035'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514036'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514037'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514038'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 6,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514039'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 41570,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 5,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df39901451403a'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 41570,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df39901451403b'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 41570,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 6,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df39901451403c'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 41570,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df39901451403d'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 28260,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 7,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df39901451403e'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 28260,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 7,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df39901451403f'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 28260,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 8,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514040'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 28260,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 7,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514041'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 28260,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 8,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514042'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 28260,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 8,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514043'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 28260,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 8,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514044'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 28260,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 8,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514045'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 28260,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 8,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514046'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 28260,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 8,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514047'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514048'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514049'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df39901451404a'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df39901451404b'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df39901451404c'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df39901451404d'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df39901451404e'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df39901451404f'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514050'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514051'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514052'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514053'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514054'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514055'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 42110,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514056'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 42110,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514057'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 42110,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514058'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 42110,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514059'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 42110,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df39901451405a'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 42130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df39901451405b'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 42130,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df39901451405c'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 42130,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df39901451405d'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 42130,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 3,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df39901451405e'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 42130,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df39901451405f'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 42130,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514060'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 42130,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514061'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 11200,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514062'),
#   'STD_YYYY': 2015,
#   'RN_INDI':
),
#   'STD_YYYY': 2004,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df39901451438b'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df39901451438c'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df39901451438d'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df39901451438e'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 3,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df39901451438f'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 3,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514390'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514391'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514392'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514393'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514394'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514395'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514396'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 89809,
#   'SEX': 2,
#   'SGG': 30170,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514397'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 89809,
#   'SEX': 2,
#   'SGG': 30170,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311be82df399014514398'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 89809,
#   'SEX': 2,
#   'SGG': 30170,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  ...]

# %%
df_BNC_V2_1 = pd.DataFrame(list_BNC_V2_1)

# %%
df_BNC_V2_1
# Out:
#                             _id  STD_YYYY  RN_INDI  SEX    SGG  GAIBJA_TYPE  \
# 0      64d311be82df399014513fb1      2002     1433    1  29140            7
# 1      64d311be82df399014513fb2      2003     1433    1  29140            7
# 2      64d311be82df399014513fb3      2004     1433    1  29140            7
# 3      64d311be82df399014513fb4      2005     1433    1  29140            7
# 4      64d311be82df399014513fb5      2006     1433    1  29140            7
# ...                         ...       ...      ...  ...    ...          ...
# 13022  64d311bf82df39901451728f      2012  3000357    2  28237            6
# 13023  64d311bf82df399014517290      2013  3000357    2  28245            2
# 13024  64d311bf82df399014517291      2014  3000357    2  28245            2
# 13025  64d311bf82df399014517292      2015  3000357    2  28245            2
# 13026  64d311bf82df399014517293      2015  3000758    1  41287            6
#
#        SMPL_TYPE_CD  CTRB_Q10 G1E_OBJ_YN  DSB_TYPE_CD  DSB_SVRT_CD_V2
# 0                 1       NaN        NaN          NaN             NaN
# 1                 1       NaN        NaN          NaN             NaN
# 2                 1       NaN        NaN          NaN             NaN
# 3                 1       NaN        NaN          NaN             NaN
# 4                 1       NaN        NaN          NaN             NaN
# ...             ...       ...        ...          ...             ...
# 13022             4       NaN        NaN          NaN             NaN
# 13023             4       6.0        NaN          NaN             NaN
# 13024             4       6.0        NaN          NaN             NaN
# 13025             4       7.0        NaN          NaN             NaN
# 13026             4       NaN        NaN          NaN             NaN
#
# [13027 rows x 11 columns]

# %%
df_BNC_V2_1.to_csv('./NSC2_BNC_V2_1.csv')
