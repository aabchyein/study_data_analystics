# %% [markdown]
# ## Quest
# - 한글 워드 클라우드 작성
# - 명사만 확인
# - 불용어처리 필요(한 글자 이하)

# %%
from wordcloud import WordCloud

# %%
# 한글 문장 리스트
sentences = [
    "오늘 날씨가 좋아서 나들이 가고 싶다.",
    "이 영화는 정말 재미있었어요.",
    "맛있는 음식을 먹으러 갈까요?",
    "운동을 하면 건강에 좋아지는 것 같아요.",
    "공부하기 싫어서 미루고 있어요.",
    "여행 계획을 세우고 있는데 어디로 갈까요?",
    "좋은 책을 읽으면 마음이 편안해져요.",
    "오늘은 친구들과 만나서 재미있게 놀았어요.",
    "새로운 언어를 배우는 것은 어려워도 흥미로워요.",
    "주말에 가족들과 함께 시간을 보내기로 했습니다."
]

# %%
from mecab import MeCab
mecab = MeCab()

# %%
# 형태 분석기 사용해 명사 추출
morphs_list = list()
for sentence in sentences :
    morphs = mecab.nouns(sentence)
    morphs_list = morphs_list + morphs
morphs_list
# Out:
# ['날씨',
#  '나',
#  '영화',
#  '음식',
#  '운동',
#  '건강',
#  '것',
#  '공부',
#  '여행',
#  '계획',
#  '어디',
#  '책',
#  '마음',
#  '편안',
#  '오늘',
#  '친구',
#  '언어',
#  '것',
#  '흥미',
#  '주말',
#  '가족',
#  '시간']

# %%
# 문장 합치기
text = ' '.join(sentences)
text
# Out:
# '오늘 날씨가 좋아서 나들이 가고 싶다. 이 영화는 정말 재미있었어요. 맛있는 음식을 먹으러 갈까요? 운동을 하면 건강에 좋아지는 것 같아요. 공부하기 싫어서 미루고 있어요. 여행 계획을 세우고 있는데 어디로 갈까요? 좋은 책을 읽으면 마음이 편안해져요. 오늘은 친구들과 만나서 재미있게 놀았어요. 새로운 언어를 배우는 것은 어려워도 흥미로워요. 주말에 가족들과 함께 시간을 보내기로 했습니다.'

# %%
# 불용어 처리 (한 글자 이하)
import re
pattern = r'[가는을에것이은를과]'
text_regex = re.sub(pattern=pattern, repl='', string=text)
text_regex
# Out:
# '오늘 날씨 좋아서 나들 고 싶다.  영화 정말 재미있었어요. 맛있 음식 먹으러 갈까요? 운동 하면 건강 좋아지  같아요. 공부하기 싫어서 미루고 있어요. 여행 계획 세우고 있데 어디로 갈까요? 좋 책 읽으면 마음 편안해져요. 오늘 친구들 만나서 재미있게 놀았어요. 새로운 언어 배우  어려워도 흥미로워요. 주말 족들 함께 시간 보내기로 했습니다.'

# %%
from collections import Counter
nouns_count = Counter(morphs_list)

# %%
font_path = 'C:/Windows/Fonts/malgun.ttf'

wordCloud = WordCloud(font_path=font_path, background_color='white')
wordCloud.generate_from_frequencies(nouns_count)

# %%
wordCloud.words_
# Out:
# {'것': 1.0,
#  '날씨': 0.5,
#  '나': 0.5,
#  '영화': 0.5,
#  '음식': 0.5,
#  '운동': 0.5,
#  '건강': 0.5,
#  '공부': 0.5,
#  '여행': 0.5,
#  '계획': 0.5,
#  '어디': 0.5,
#  '책': 0.5,
#  '마음': 0.5,
#  '편안': 0.5,
#  '오늘': 0.5,
#  '친구': 0.5,
#  '언어': 0.5,
#  '흥미': 0.5,
#  '주말': 0.5,
#  '가족': 0.5,
#  '시간': 0.5}

# %%
import matplotlib.pyplot as plt
plt.imshow(wordCloud)
plt.axis('off')
plt.show()
